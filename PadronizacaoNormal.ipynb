# %% [markdown]
# ##Padronização e Normalização

# %% [markdown]
# # Nova seção

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('004-Dataset(a).xlsx')

# %%
df.describe()
# Out:
#                X1          X2           Y
# count  500.000000  500.000000  500.000000
# mean    50.164000   50.128000  155.562000
# std     29.244411   28.529133   64.567423
# min      0.000000    0.000000    2.000000
# 25%     25.000000   26.000000  105.000000
# 50%     50.500000   53.000000  157.000000
# 75%     75.000000   73.000000  207.000000
# max    100.000000  100.000000  292.000000

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
min_value = df.min()
max_value = df.max()
mean_value = df.mean()
std_value = df.std()

# %%
df
# Out:
#      X1  X2    Y
# 0    70  26  126
# 1    82  85  261
# 2    72  11  102
# 3     0  56  112
# 4    27  88  212
# ..   ..  ..  ...
# 495  99  89  283
# 496  85  31  153
# 497  37  18   75
# 498   8  41   94
# 499  74  15  110
#
# [500 rows x 3 columns]

# %%
df.iloc[1,0]
# Out:
# 82

# %%
df.iloc[2,1]
# Out:
# 11

# %% [markdown]
# ###Normalização

# %%
x_normalization = (df.iloc[2,1] - min_value[:1] / max_value[:1] - min_value[:1])

# %%
x_normalization
# Out:
# X1    11.0
# dtype: float64

# %% [markdown]
# ###Padronização

# %%
x_standarization = (df.iloc[0,0] -  mean_value[0:] / mean_value[0:] - std_value[0:])

# %%
x_standarization
# Out:
# X1    39.755589
# X2    40.470867
# Y      4.432577
# dtype: float64

# %% [markdown]
# #Usando Sclean - Scikitlearn

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler()

# %%
scaler.transform(df)
# Out:
# array([[ 0.67896275, -0.84657897, -0.45830552],
#        [ 1.08970852,  1.22355363,  1.63462613],
#        [ 0.74742038, -1.37288387, -0.83038226],
#        ...,
#        [-0.45058811, -1.12727492, -1.24896859],
#        [-1.44322371, -0.32027407, -0.95440784],
#        [ 0.81587801, -1.2325359 , -0.70635668]])

# %%
ScalerData = pd.DataFrame(data=scaler.transform(df))

# %%
ScalerData.columns = {'x1','x2', 'x3'}

# %%
ScalerData.plot.kde()
# Out:
# <Axes: ylabel='Density'>
